# %% [markdown]
# # Social Network — Full Graph View
#
# The diagram below shows **all 10 people, 5 companies, 10 cities and 8 skills** together with every edge in the demo dataset seeded by `scripts/seed_social_network.py`.
#
# > Use this as a visual reference while running queries in `social_network_demo.ipynb`.
#
# | Colour | Meaning |
# |:-------|:--------|
# | 🔵 Blue nodes | `Person` |
# | 🟢 Green nodes | `Company` |
# | 🟡 Yellow nodes | `City` |
# | 🟣 Purple nodes | `Skill` |
# | → `KNOWS` | Person–Person relationship |
# | → `WORKS_AT` | Person → Company |
# | → `LIVES_IN` | Person → City |
# | → `HAS_SKILL` | Person → Skill |
# | → `LOCATED_IN` | Company → City |

# %% [markdown]
# <img
#   src="image/Social+Networking-Full-Graph.png"
#   alt="Social Network Full Graph"
#   style="max-width:100%; height:auto; display:block; margin:1.5em auto;"
# />

# %% [markdown]
# ## Dataset at a glance
#
# ### People
#
# | # | Person | Age | City |
# |---|--------|-----|------|
# | 1 | Alice | 29 | San Francisco |
# | 2 | Bob | 34 | New York |
# | 3 | Carol | 27 | London |
# | 4 | Dave | 41 | Berlin |
# | 5 | Eve | 25 | Paris |
# | 6 | Frank | 38 | Tokyo |
# | 7 | Grace | 32 | Sydney |
# | 8 | Hank | 45 | Toronto |
# | 9 | Iris | 30 | Singapore |
# | 10 | Jake | 22 | Amsterdam |
#
# ### Companies
#
# | # | Company | Industry | HQ City |
# |---|---------|----------|---------|
# | 1 | TechCorp | Technology | San Francisco |
# | 2 | FinanceHub | Finance | London |
# | 3 | DataStream | Data Analytics | Berlin |
# | 4 | CloudNine | Cloud Services | New York |
# | 5 | AIWorks | AI/ML | Singapore |
#
# ### Edge counts
#
# | Edge | Count |
# |:-----|------:|
# | `KNOWS` | 10 |
# | `WORKS_AT` | 10 |
# | `LIVES_IN` | 10 |
# | `HAS_SKILL` | 15 |
# | `LOCATED_IN` | 5 |

# %% [markdown]
# ---
#
# Open **`social_network_demo.ipynb`** to run live Gremlin queries against this graph.
